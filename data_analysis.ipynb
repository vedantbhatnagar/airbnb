# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('listings.csv.gz')

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20210208155251   2021-02-11
# 1  20168  https://www.airbnb.com/rooms/20168  20210208155251   2021-02-11
# 2  25428  https://www.airbnb.com/rooms/25428  20210208155251   2021-02-10
# 3  27886  https://www.airbnb.com/rooms/27886  20210208155251   2021-02-11
# 4  28871  https://www.airbnb.com/rooms/28871  20210208155251   2021-02-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely, spacious 1 bed apt in Center(with lift)
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# ...

# %%
df.shape
# Out:
# (18291, 74)

# %%
df_numeric = df.select_dtypes(include=['float64'])

# %%
df_string = df.select_dtypes(include=['object'])

# %%
df_int = df.select_dtypes(include=['int'])

# %%
print(df_numeric.shape)
print(df_string.shape)
print(df_int.shape)
# Out:
# (18291, 24)
# (18291, 33)
# (18291, 17)

# %%
df_numeric.describe()
# Out:
#        host_listings_count  host_total_listings_count  \
# count         18228.000000               18228.000000
# mean              3.244459                   3.244459
# std              56.575963                  56.575963
# min               0.000000                   0.000000
# 25%               1.000000                   1.000000
# 50%               1.000000                   1.000000
# 75%               1.000000                   1.000000
# max            7235.000000                7235.000000
#
#        neighbourhood_group_cleansed      latitude     longitude  bathrooms  \
# count                           0.0  18291.000000  18291.000000        0.0
# mean                            NaN     52.365478      4.889504        NaN
# std                             NaN      0.016559      0.035833        NaN
# min                             NaN     52.289270      4.755940        NaN
# 25%                             NaN     52.355100      4.863920        NaN
# ...

# %%
df_numeric.isnull().sum()
# Out:
# host_listings_count                63
# host_total_listings_count          63
# neighbourhood_group_cleansed    18291
# latitude                            0
# longitude                           0
# bathrooms                       18291
# bedrooms                          997
# beds                              105
# minimum_minimum_nights              3
# maximum_minimum_nights              3
# minimum_maximum_nights              3
# maximum_maximum_nights              3
# minimum_nights_avg_ntm              3
# maximum_nights_avg_ntm              3
# calendar_updated                18291
# review_scores_rating             2632
# review_scores_accuracy           2642
# review_scores_cleanliness        2642
# review_scores_checkin            2650
# review_scores_communication      2643
# review_scores_location           2648
# review_scores_value              2648
# license                         18291
# reviews_per_month                2389
# dtype: int64

# %%
drop_list = ['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated', 'license']

# %%
drop_list.extend(['latitude', 'longitude'])

# %%
df_numeric.drop(columns = drop_list, axis = 1).head()
# Out:
#    host_listings_count  host_total_listings_count  bedrooms  beds  \
# 0                  1.0                        1.0       1.0   2.0
# 1                  2.0                        2.0       1.0   1.0
# 2                  2.0                        2.0       1.0   1.0
# 3                  1.0                        1.0       1.0   1.0
# 4                  2.0                        2.0       1.0   1.0
#
#    minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 0                     3.0                     3.0                  1125.0
# 1                     1.0                     4.0                    60.0
# 2                    14.0                    14.0                   180.0
# 3                     2.0                     2.0                  1125.0
# 4                     2.0                     2.0                  1825.0
#
#    maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# ...

# %%
df_numeric.drop(columns = drop_list, axis = 1).describe()
# Out:
#        host_listings_count  host_total_listings_count      bedrooms  \
# count         18228.000000               18228.000000  17294.000000
# mean              3.244459                   3.244459      1.534405
# std              56.575963                  56.575963      0.959211
# min               0.000000                   0.000000      1.000000
# 25%               1.000000                   1.000000      1.000000
# 50%               1.000000                   1.000000      1.000000
# 75%               1.000000                   1.000000      2.000000
# max            7235.000000                7235.000000     50.000000
#
#                beds  minimum_minimum_nights  maximum_minimum_nights  \
# count  18186.000000            18288.000000            18288.000000
# mean       1.765259                3.683454                3.861494
# std        1.444775               16.287296               16.389708
# min        0.000000                1.000000                1.000000
# ...

# %%
df_int.describe()
# Out:
#                  id     scrape_id       host_id  accommodates  minimum_nights  \
# count  1.829100e+04  1.829100e+04  1.829100e+04  18291.000000    18291.000000
# mean   2.064229e+07  2.021021e+13  6.705998e+07      2.837570        3.727407
# std    1.285836e+07  0.000000e+00  8.666877e+07      1.282434       16.331468
# min    2.818000e+03  2.021021e+13  3.159000e+03      0.000000        1.000000
# 25%    1.010732e+07  2.021021e+13  9.282300e+06      2.000000        2.000000
# 50%    1.911168e+07  2.021021e+13  2.810956e+07      2.000000        2.000000
# 75%    3.039472e+07  2.021021e+13  8.650474e+07      4.000000        3.000000
# max    4.807786e+07  2.021021e+13  3.871652e+08     16.000000     1001.000000
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# count    18291.000000     18291.000000     18291.000000     18291.000000
# mean       611.559565         5.950467        12.473621        19.262315
# ...

# %%
df_int.isnull().sum()
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# accommodates                                    0
# minimum_nights                                  0
# maximum_nights                                  0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# dtype: int64

# %%
df_string.head()
# Out:
#                           listing_url last_scraped  \
# 0   https://www.airbnb.com/rooms/2818   2021-02-11
# 1  https://www.airbnb.com/rooms/20168   2021-02-11
# 2  https://www.airbnb.com/rooms/25428   2021-02-10
# 3  https://www.airbnb.com/rooms/27886   2021-02-11
# 4  https://www.airbnb.com/rooms/28871   2021-02-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely, spacious 1 bed apt in Center(with lift)
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Lovely apt in Centre ( lift & fireplace) near ...
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  <b>The space</b><br />In a monumental house ri...
#
# ...

# %%
df_string.columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type',
#        'bathrooms_text', 'amenities', 'price', 'has_availability',
#        'calendar_last_scraped', 'first_review', 'last_review',
#        'instant_bookable'],
#       dtype='object')

# %%
drop_list_string = ['listing_url', 'last_scraped', 'name', 'picture_url', 'host_url', 'host_name', 'host_thumbnail_url', \
                    'host_picture_url']
potential_important_string = ['host_since', 'host_location', 'response_rate', 'host_acceptance_rate', 'host_is_superhost'\
                             'host_identity_vrified', 'some sort of location', 'neighbourhood', 'neighbourhood_cleansed'\
                             'property_type', 'room_type', 'bathrooms_text', 'instant_bookable']
maybe_string = ['description', 'host_about', 'neighborhood_overview', 'host_location', 'host_response_time', \
                'host_neighborhood', 'host_verifications', 'host_has_profile_pic', 'amenities', 'has_availability']
target = ['price']

# %%
df_string['host_about'][0]
# Out:
# 'Upon arriving in Amsterdam, one can imagine asking oneself: Where is the fun nightlife? What are the local hot spots? \r\n\r\nHow can I experience the real life in this city? I  offer you the opportunity to act, eat and sleep like-a-local!  \r\n\r\nI provide the traveler with the opportunity to connect with the local life in Amsterdam.'

# %%
df_string['description'][0]
# Out:
# 'Quiet Garden View Room & Super Fast WiFi<br /><br /><b>The space</b><br />I\'m renting a bedroom (room overlooking the garden) in my apartment in Amsterdam, <br /><br />The room is located to the east of the city centre in a quiet, typical Amsterdam neighbourhood the "Indische Buurt". Amsterdam’s historic centre is less than 15 minutes away by bike or tram.<br /><br /><br />The features of the room are:<br /><br />- Twin beds (80 x 200 cm, down quilts and pillows) <br />- 2 pure cotton towels for each guest <br />- reading lamps<br />- bedside table<br />- wardrobe<br />- table with chairs<br />- tea and coffee making facilities<br />- mini bar<br />- alarm clock<br />- Hi-Fi system with cd player, connection for mp3 player / phone<br />- map of Amsterdam and public transport<br />- Wi-Fi Internet connection <br /><br />Extra services:<br /><br />- Bike rental'

# %%
df_string['neighborhood_overview'][0]
# Out:
# 'Indische Buurt ("Indies Neighborhood") is a neighbourhood in the eastern portion of the city of Amsterdam, in the Dutch province of Noord-Holland. The name dates from the early 20th century and is derived from the fact that the neighbourhood\'s streets are named after islands and other geographical concepts in the former Dutch colony of the Dutch East Indies. The first street was named in 1902. In 2003, there were around 23,357 inhabitants. The neighbourhood is bounded on the west by the railroad Amsterdam - Hilversum (with the Muiderpoort Station), on the east side by Flevopark, on the north side by Zeeburgerdijk and on the south side by the Ringvaart Watergraafsmeer. Indische Buurt is the oldest part of the Zeeburg district and is very ethnically diverse, and a high percentage of the population is of immigrant origin (for Zeeburg this is already high at 55%, but higher in the Indische Buurt) and there are an estimated 100 languages spoken.'

# %%
df_string['last_scraped'].value_counts()
# Out:
# 2021-02-09    7486
# 2021-02-10    6051
# 2021-02-11    3301
# 2021-02-08    1453
# Name: last_scraped, dtype: int64

# %%
df_string['host_location'].value_counts()
# Out:
# Amsterdam, North Holland, Netherlands                    10046
# Amsterdam, North Holland, The Netherlands                 3515
# NL                                                        1549
# Amsterdam, Noord-Holland, The Netherlands                 1153
# Netherlands                                                520
#                                                          ...
# Patras, Greece                                               1
# Mannheim, Baden-Wurttemberg, Germany                         1
# Coux-et-Bigaroque-Mouzens, Nouvelle-Aquitaine, France        1
# Madison, Wisconsin, United States                            1
# Caen, Normandy, France                                       1
# Name: host_location, Length: 534, dtype: int64

# %%
df_string['host_response_time'].value_counts()
# Out:
# within an hour        1800
# within a day           900
# within a few hours     838
# a few days or more     399
# Name: host_response_time, dtype: int64

# %%
df_string['host_response_rate'].value_counts()
# Out:
# 100%    2794
# 0%       286
# 50%      106
# 90%       81
# 70%       69
# 60%       63
# 67%       55
# 80%       55
# 75%       53
# 33%       43
# 89%       41
# 88%       30
# 93%       23
# 86%       22
# 96%       17
# 83%       16
# 82%       15
# 63%       15
# 41%       13
# 65%       12
# 40%       12
# 77%       11
# 95%       11
# 38%        7
# 91%        7
# 72%        6
# 92%        6
# 57%        6
# 97%        5
# 25%        5
# 78%        5
# 85%        4
# 17%        4
# 30%        4
# 29%        3
# 20%        3
# 64%        3
# 10%        3
# 99%        3
# 94%        3
# 43%        2
# 71%        2
# 53%        2
# 31%        2
# 73%        2
# 44%        2
# 56%        2
# 14%        1
# 58%        1
# 11%        1
# Name: host_response_rate, dtype: int64

# %%
df_string['host_acceptance_rate'].value_counts()
# Out:
# 100%    3638
# 0%       812
# 50%      407
# 99%      253
# 67%      217
#         ...
# 4%         1
# 41%        1
# 23%        1
# 15%        1
# 7%         1
# Name: host_acceptance_rate, Length: 89, dtype: int64

# %%
df_string['host_is_superhost'].value_counts()
# Out:
# f    15849
# t     2379
# Name: host_is_superhost, dtype: int64

# %%
df_string['host_neighbourhood'].value_counts()
# Out:
# Oud-West             2482
# De Pijp              1061
# Grachtengordel        728
# Jordaan               685
# Oosterparkbuurt       675
#                      ...
# Sant Antoni             1
# La Latina               1
# Beguinage-Dixmude       1
# Recoleta                1
# Le Plateau              1
# Name: host_neighbourhood, Length: 76, dtype: int64

# %%
df_string['host_verifications']
# Out:
# 0        ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 1        ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 2                            ['email', 'phone', 'reviews']
# 3        ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 4        ['email', 'phone', 'reviews', 'jumio', 'offlin...
#                                ...
# 18286                ['email', 'phone', 'identity_manual']
# 18287    ['email', 'phone', 'facebook', 'reviews', 'jum...
# 18288                          ['email', 'phone', 'jumio']
# 18289    ['phone', 'facebook', 'jumio', 'offline_govern...
# 18290                                   ['email', 'phone']
# Name: host_verifications, Length: 18291, dtype: object

# %%
df_string['host_has_profile_pic'].value_counts()
# maybe category due to lack of variance
# Out:
# t    18199
# f       29
# Name: host_has_profile_pic, dtype: int64

# %%
df_string['host_identity_verified'].value_counts()
# Out:
# t    11918
# f     6310
# Name: host_identity_verified, dtype: int64

# %%
df_string['neighbourhood'].value_counts()
# Out:
# Amsterdam, Noord-Holland, Netherlands             9534
# Amsterdam, North Holland, Netherlands             1490
# Amsterdam, NH, Netherlands                         700
# Amsterdam, Netherlands                             110
# Amsterdam-Zuidoost, Noord-Holland, Netherlands      57
#                                                   ...
# Halfweg, NH, Netherlands                             1
# Amsterdam, NB, Netherlands                           1
# Amsterdam, TL, Netherlands                           1
# Amsterdão, North Holland, Netherlands                1
# Amsterdam, GA, Netherlands                           1
# Name: neighbourhood, Length: 67, dtype: int64

# %%
df_string['neighbourhood_cleansed'].value_counts()
# Out:
# De Baarsjes - Oud-West                    3044
# De Pijp - Rivierenbuurt                   2269
# Centrum-West                              2000
# Centrum-Oost                              1560
# Westerpark                                1395
# Zuid                                      1309
# Oud-Oost                                  1181
# Bos en Lommer                             1047
# Oostelijk Havengebied - Indische Buurt     875
# Oud-Noord                                  586
# Watergraafsmeer                            530
# IJburg - Zeeburgereiland                   423
# Slotervaart                                411
# Noord-West                                 369
# Noord-Oost                                 255
# Buitenveldert - Zuidas                     252
# Geuzenveld - Slotermeer                    214
# De Aker - Nieuw Sloten                     126
# Osdorp                                     125
# Gaasperdam - Driemond                      121
# ...

# %%
df_string['property_type'].value_counts()
# Out:
# Entire apartment                     11393
# Private room in apartment             2218
# Entire house                          1198
# Entire townhouse                       472
# Private room in bed and breakfast      344
#                                      ...
# Earth house                              1
# Entire chalet                            1
# Entire home/apt                          1
# Bus                                      1
# Tipi                                     1
# Name: property_type, Length: 65, dtype: int64

# %%
df_string['room_type'].value_counts()
# Out:
# Entire home/apt    14283
# Private room        3831
# Hotel room           127
# Shared room           50
# Name: room_type, dtype: int64

# %%
df_string['bathrooms_text'].value_counts()
# Out:
# 1 bath               10677
# 1.5 baths             3473
# 1 shared bath         1210
# 1 private bath        1043
# 2 baths                802
# 1.5 shared baths       466
# 2.5 baths              239
# 3 baths                 96
# 3.5 baths               43
# Half-bath               39
# 0 baths                 38
# Shared half-bath        32
# 2 shared baths          29
# 0 shared baths          15
# 4 baths                 13
# Private half-bath       11
# 3 shared baths          10
# 3.5 shared baths         8
# 2.5 shared baths         6
# 4 shared baths           5
# 4.5 baths                4
# 8 baths                  3
# 5 baths                  2
# 6 baths                  2
# 12 baths                 1
# 13 baths                 1
# 5.5 baths                1
# Name: bathrooms_text, dtype: int64

# %%
df_string['amenities'].value_counts()
# Out:
# ["Long term stays allowed"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       45
# ...

# %%
df_string['has_availability'].value_counts()
# maybe due to lack of variance
# Out:
# t    17889
# f      402
# Name: has_availability, dtype: int64

# %%
df_string['instant_bookable'].value_counts()
# Out:
# f    13914
# t     4377
# Name: instant_bookable, dtype: int64

# %%
df_string['has_availability'].value_counts()
